# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import math

# %%
Nspin = 5000
Niter = 10000000
dt = 0.01
sigma = 2
p = 2/3. 

m = np.zeros(Nspin) + 2*p - 1
x = np.random.normal(0,sigma,Nspin)
M = np.zeros(Niter) + 2*p - 1

for j in range(0,Niter):
        M[j] = np.mean(m)
        k = np.random.randint(0, Nspin-1)
        m[k] = m[k] + 2*np.sign(x[k] + m[k] + M[j])*dt - 2*m[k]*dt

# %%
plt.plot(x,m,'ro')
plt.xlabel('x_i')
plt.ylabel('m_i')
plt.show()

plt.plot(M)
plt.xlabel('time')
plt.ylabel('M(t)')
plt.show()
